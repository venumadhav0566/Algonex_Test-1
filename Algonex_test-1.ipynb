# %%
#mysql
1.Create table emp(emp_id int, name varchar(10), department varchar(19), salary int, joining_date date);

insert into emp values(111, 'Venu', 'IT', 500000 , '12-11-2025'),(222, 'Santhosh', 'HR', 600000, '01-02-2026'),(333, 'karthik', 'TL', '04-05-2020');

select max(salary) as highest salary
from Emp
where salary < (select salary, from emp)

# %%
2.Create table emp(emp_id int, name varchar(10), department varchar(19), salary int, joining_date date);

insert into emp values(111, 'Venu', 'IT', 500000 , '12-11-2025'),(222, 'Santhosh', 'HR', 600000, '01-02-2026'),(333, 'karthik', 'TL', '04-05-2020');

select department, avg(salary) as avg_salary
from emp
group by department;

# %%
4. Create table emp(emp_id int, name varchar(10), department varchar(19), salary int, joining_date date);

insert into emp values(111, 'Venu', 'IT', 500000 , '12-11-2025'),(222, 'Santhosh', 'HR', 600000, '01-02-2026'),(333, 'karthik', 'TL',500000, '04-05-2020'),(444, 'somu', 'IT', 30000, '02-01-2025'),(555, 'vishnu', 'HR', 250000);
select salary
high(salary) as hightes_salary
from emp
order by salary
limit 3

# %%
5.Create table emp(emp_id int, name varchar(10), department varchar(19), salary int, joining_date date);

insert into emp values(111, 'Venu', 'IT', 500000 , '12-11-2025'),(222, 'Santhosh', 'HR', 600000, '01-02-2026'),(333, 'karthik', 'TL',500000, '04-05-2020'),(444, 'somu', 'IT', 30000, '02-01-2025'),(555, 'vishnu', 'HR', 250000);

select department,
count(*) as total_employess
from emp
group by department

# %%
7.Create table emp(emp_id int, name varchar(10), department varchar(19), salary int, joining_date date,rank int);

insert into emp values(111, 'Venu', 'IT', 500000 , '12-11-2025', 2),(222, 'Santhosh', 'HR', 600000, '01-02-2026', 3),(333, 'karthik', 'TL',500000, '04-05-2020', 1),(444, 'somu', 'IT', 30000, '02-01-2025', 4),(555, 'vishnu', 'HR', 250000, '03-03-2023', 1);

select salary, rank
from emp
partition by deparment
rank() as highest salary
over() order by salary

# %%
#python
1.def Algonex(
   a = {'a':1,'l':1,'g':1,'0':1,'n':1,'e':1,'x':1}
):
   return a
print(Algonex())
# Out:
# {'a': 1, 'l': 1, 'g': 1, '0': 1, 'n': 1, 'e': 1, 'x': 1}

# %%
#5
Students = [
    ("venu",85),
    ("santhosh",92),
    ("karthik",78),
    ("vishnu",95)
];
result = sorted(Students, key=lambda x: x[0])
print(result)
# Out:
# [('karthik', 78), ('santhosh', 92), ('venu', 85), ('vishnu', 95)]

# %%
#3
emp = [
    ("john",50000),
    ("David",70000),
    ("Smith",40000),
    ("Alice",90000)
]
def salary_processor(emp_list):
    highest = max(emp_list, key=lambda x: x[1])
    lowest = min(emp_list, key=lambda x: x[1])
    total_salary = 0
    for name , salary in emp_list:
        total_salary = salary
        average_salary = total_salary / emp(list)
        print(highest = highest[0])
        print(lowest = lowest[0])
        print(Average = avg[1])

# %%
def test():
    pass
